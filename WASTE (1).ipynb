# %% [markdown]
# ## 1. Install

# %%
# !pip install -q ultralytics roboflow pyyaml
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.0/46.0 kB 1.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 54.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 302.3/302.3 kB 13.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 34.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.4/5.4 MB 105.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.4/58.4 kB 5.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.2/66.2 kB 3.5 MB/s eta 0:00:00

# %% [markdown]
# ## 2. Imports

# %%
import os, glob, yaml, shutil
from collections import Counter, defaultdict
from getpass import getpass
import matplotlib.pyplot as plt
from roboflow import Roboflow
from ultralytics import YOLO
# Out:
# Creating new Ultralytics Settings v0.0.8 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart#ultralytics-settings.

# %% [markdown]
# ## 3. Roboflow login

# %%
# !pip install roboflow
# Out:
# Requirement already satisfied: roboflow in /usr/local/lib/python3.13/dist-packages (1.4.1)
# Requirement already satisfied: certifi in /usr/local/lib/python3.13/dist-packages (from roboflow) (2026.7.22)
# Requirement already satisfied: idna>=3.7 in /usr/local/lib/python3.13/dist-packages (from roboflow) (3.19)
# Requirement already satisfied: cycler in /usr/local/lib/python3.13/dist-packages (from roboflow) (0.12.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.13/dist-packages (from roboflow) (1.5.0)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.13/dist-packages (from roboflow) (3.10.0)
# Requirement already satisfied: numpy<2.4,>=1.18.5 in /usr/local/lib/python3.13/dist-packages (from roboflow) (2.1.3)
# Requirement already satisfied: opencv-python-headless>=4.10.0 in /usr/local/lib/python3.13/dist-packages (from roboflow) (5.0.0.93)
# Requirement already satisfied: Pillow>=7.1.2 in /usr/local/lib/python3.13/dist-packages (from roboflow) (11.3.0)
# Requirement already satisfied: pi-heif<2 in /usr/local/lib/python3.13/dist-packages (from roboflow) (1.4.0)
# Requirement already satisfied: pillow-avif-plugin<2 in /usr/local/lib/python3.13/dist-packages (from roboflow) (1.6.0)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.13/dist-packages (from roboflow) (2.9.0.post0)
# Requirement already satisfied: python-dotenv in /usr/local/lib/python3.13/dist-packages (from roboflow) (1.2.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.13/dist-packages (from roboflow) (2.32.4)
# Requirement already satisfied: six in /usr/local/lib/python3.13/dist-packages (from roboflow) (1.17.0)
# Requirement already satisfied: urllib3>=1.26.6 in /usr/local/lib/python3.13/dist-packages (from roboflow) (2.5.0)
# Requirement already satisfied: tqdm>=4.41.0 in /usr/local/lib/python3.13/dist-packages (from roboflow) (4.67.3)
# Requirement already satisfied: PyYAML>=5.3.1 in /usr/local/lib/python3.13/dist-packages (from roboflow) (6.0.3)
# Requirement already satisfied: requests_toolbelt in /usr/local/lib/python3.13/dist-packages (from roboflow) (1.0.0)
# Requirement already satisfied: filetype in /usr/local/lib/python3.13/dist-packages (from roboflow) (1.2.0)
# Requirement already satisfied: typer<0.26,>=0.12.0 in /usr/local/lib/python3.13/dist-packages (from roboflow) (0.25.1)
# Requirement already satisfied: click>=8.0 in /usr/local/lib/python3.13/dist-packages (from roboflow) (8.4.2)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.13/dist-packages (from typer<0.26,>=0.12.0->roboflow) (1.5.4)
# Requirement already satisfied: rich>=13.8.0 in /usr/local/lib/python3.13/dist-packages (from typer<0.26,>=0.12.0->roboflow) (13.9.4)
# Requirement already satisfied: annotated-doc>=0.0.2 in /usr/local/lib/python3.13/dist-packages (from typer<0.26,>=0.12.0->roboflow) (0.0.5)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.13/dist-packages (from matplotlib->roboflow) (1.3.3)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.13/dist-packages (from matplotlib->roboflow) (4.63.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.13/dist-packages (from matplotlib->roboflow) (26.3)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.13/dist-packages (from matplotlib->roboflow) (3.3.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.13/dist-packages (from requests->roboflow) (3.4.9)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.13/dist-packages (from rich>=13.8.0->typer<0.26,>=0.12.0->roboflow) (4.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.13/dist-packages (from rich>=13.8.0->typer<0.26,>=0.12.0->roboflow) (2.21.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.13/dist-packages (from markdown-it-py>=2.2.0->rich>=13.8.0->typer<0.26,>=0.12.0->roboflow) (0.1.2)

# %%
rf = Roboflow(api_key="Q1FQoXMlwdOFvth4FMlY")
project = rf.workspace("noora-hussain-s-workspace").project("ecovision-quw28")
version = project.version(2)
dataset = version.download("yolo26")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# Downloading Dataset Version Zip in EcoVision-2 to yolo26:: 100%|██████████| 4928456/4928456 [04:50<00:00, 16945.31it/s]
# Extracting Dataset Version Zip to EcoVision-2 in yolo26:: 100%|██████████| 63639/63639 [00:36<00:00, 1750.51it/s]

# %% [markdown]
# ## 4. Download

# %%
DATASET_DIR = dataset.location
yaml_path = os.path.join(DATASET_DIR, "data.yaml")
print(DATASET_DIR)
# Out:
# /content/EcoVision-2

# %% [markdown]
# ## 5. Check classes

# %%
with open(yaml_path, "r") as f:
    data = yaml.safe_load(f)

class_names = data["names"]
print(class_names)
# Out:
# ['General Waste', 'Glass', 'Metals', 'Paper', 'Plastics']

# %% [markdown]
# ## 6. Dataset counts

# %%
for split in ["train", "valid", "test"]:
    print(split, ":", len(glob.glob(f"{DATASET_DIR}/{split}/images/*")))
# Out:
# train : 28182
# valid : 2548
# test : 1087

# %% [markdown]
# ## 7. Object counts

# %%
def names_list(names):
    if isinstance(names, dict):
        return [names.get(i, names.get(str(i))) for i in range(len(names))]
    return list(names)

class_list = names_list(class_names)
class_counts = Counter()
images_per_class = defaultdict(set)
total_images = 0

for split in ["train", "valid", "test"]:
    total_images += len(glob.glob(f"{DATASET_DIR}/{split}/images/*"))

    for label_file in glob.glob(f"{DATASET_DIR}/{split}/labels/*.txt"):
        seen = set()

        for line in open(label_file):
            parts = line.split()
            if not parts:
                continue
            cid = int(parts[0])
            class_counts[cid] += 1
            seen.add(cid)

        for cid in seen:
            images_per_class[cid].add(label_file)

total_objects = sum(class_counts.values())

print("Total images:", total_images)
print("Total objects:", total_objects)
print("Average objects/image:", round(total_objects / total_images, 2))

for i, name in enumerate(class_list):
    print(f"{name}: {class_counts[i]} objects | {len(images_per_class[i])} images")
# Out:
# Total images: 31817
# Total objects: 50098
# Average objects/image: 1.57
# General Waste: 9107 objects | 5334 images
# Glass: 9079 objects | 6400 images
# Metals: 12518 objects | 6037 images
# Paper: 9481 objects | 6194 images
# Plastics: 9913 objects | 6612 images

# %% [markdown]
# ## 8. Class chart

# %%
counts = [class_counts[i] for i in range(len(class_list))]

plt.figure(figsize=(12, 6))
plt.bar(class_list, counts)
plt.xlabel("Garbage Class")
plt.ylabel("Annotated Objects")
plt.title("Garbage Objects per Class (After Balancing Plastics)")
plt.xticks(rotation=45, ha="right")
plt.tight_layout()
plt.show()

# %% [markdown]
# ## 9. Baseline

# %%
model = YOLO("yolo26n.pt")

test_images = glob.glob(f"{DATASET_DIR}/test/images/*")
if not test_images:
    raise ValueError("No test images found.")

baseline = model(test_images[0])
baseline[0].show()
# Out:
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolo26n.pt to 'yolo26n.pt': 100% ━━━━━━━━━━━━ 5.3MB 213.6MB/s 0.0s
#
# image 1/1 /content/EcoVision-2/test/images/151dark7_jpg.rf.2a57d7a6999fc6384c640779737b360c.jpg: 640x448 1 wine glass, 33.6ms
# Speed: 114.1ms preprocess, 33.6ms inference, 2.4ms postprocess per image at shape (1, 3, 640, 448)
# <PIL.Image.Image image mode=RGB size=408x612>

# %% [markdown]
# ## 10. Train with early stopping

# %%
yaml_path = os.path.join(DATASET_DIR, "data.yaml")

shutil.rmtree('/content/runs/garbage_detection/v1', ignore_errors=True)

model = YOLO("yolo26n.pt")

model.train(
    data=yaml_path,
    epochs=10,
    imgsz=640,
    batch=16,
    patience=15,
    cache=True,
    project="/content/runs/garbage_detection",
    name="v1"
)
# Out:
# Ultralytics 8.4.135 🚀 Python-3.13.15 torch-2.11.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# engine/trainer: agnostic_nms=False, amp=True, angle=1.0, augment=False, auto_augment=randaugment, batch=16, bgr=0.0, box=7.5, cache=True, cfg=None, channels_last=None, classes=None, close_mosaic=10, cls=0.5, cls_pw=0.0, cls_remap=True, compile=False, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=False, cutmix=0.0, data=/content/EcoVision-2/data.yaml, degrees=0.0, deterministic=True, device=, dfl=1.5, dgrad=0.5, dis=6.0, distill_model=None, dlam=1.0, dlog=1.0, dnn=False, dropout=0.0, dynamic=False, embed=None, end2end=None, epochs=10, erasing=0.4, exist_ok=False, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, imgsz=640, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.01, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.0, mode=train, model=yolo26n.pt, momentum=0.937, mosaic=1.0, multi_scale=0.0, name=v1, nbs=64, nms=False, opset=None, optimize=False, optimizer=auto, overlap_mask=True, patience=15, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=/content/runs/garbage_detection, quantize=None, rect=False, resume=False, retina_masks=False, rle=1.0, save=True, save_conf=False, save_crop=False, save_dir=/content/runs/garbage_detection/v1, save_frames=False, save_json=False, save_period=-1, save_txt=False, scale=0.5, seed=0, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=detect, time=None, tracker=tracktrack.yaml, translate=0.1, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3.0, warmup_momentum=0.8, weight_decay=0.0005, workers=8, workspace=None
# Downloading https://ultralytics.com/assets/Arial.ttf to '/root/.config/Ultralytics/Arial.ttf': 100% ━━━━━━━━━━━━ 755.1KB 102.8MB/s 0.0s
# Overriding model.yaml nc=80 with nc=5
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       464  ultralytics.nn.modules.conv.Conv             [3, 16, 3, 2]
#   1                  -1  1      4672  ultralytics.nn.modules.conv.Conv             [16, 32, 3, 2]
#   2                  -1  1      6640  ultralytics.nn.modules.block.C3k2            [32, 64, 1, False, 0.25]
#   3                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]
#   4                  -1  1     26080  ultralytics.nn.modules.block.C3k2            [64, 128, 1, False, 0.25]
#   5                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#   6                  -1  1     87040  ultralytics.nn.modules.block.C3k2            [128, 128, 1, True]
#   7                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
#   8                  -1  1    346112  ultralytics.nn.modules.block.C3k2            [256, 256, 1, True]
#   9                  -1  1    164608  ultralytics.nn.modules.block.SPPF            [256, 256, 5, 3, True]
#  10                  -1  1    249728  ultralytics.nn.modules.block.C2PSA           [256, 256, 1]
#  11                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  12             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  13                  -1  1    119808  ultralytics.nn.modules.block.C3k2            [384, 128, 1, True]
#  14                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  15             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  16                  -1  1     34304  ultralytics.nn.modules.block.C3k2            [256, 64, 1, True]
#  17                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]
#  18            [-1, 13]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  19                  -1  1     95232  ultralytics.nn.modules.block.C3k2            [192, 128, 1, True]
#  20                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#  21            [-1, 10]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  22                  -1  1    463104  ultralytics.nn.modules.block.C3k2            [384, 256, 1, True, 0.5, True]
#  23        [16, 19, 22]  1    243126  ultralytics.nn.modules.head.Detect           [5, 1, True, [64, 128, 256]]
# YOLO26n summary: 260 layers, 2,505,750 parameters, 2,505,750 gradients, 5.9 GFLOPs
#
# Transferred 606/708 items from pretrained weights
# AMP: running Automatic Mixed Precision (AMP) checks...
# AMP: downloading yolo26n.pt for AMP checks (one-time, not used for training)...
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolo26n.pt to 'weights/yolo26n.pt': 100% ━━━━━━━━━━━━ 5.3MB 189.1MB/s 0.0s
# AMP: checks passed ✅
# train: Fast image access ✅ (ping: 0.0±0.0 ms, read: 733.2±1284.9 MB/s, size: 75.7 KB)
# train: Scanning /content/EcoVision-2/train/labels... 28182 images, 3322 backgrounds, 398 corrupt: 100% ━━━━━━━━━━━━ 28182/28182 924.3it/s 30.5s
# train: /content/EcoVision-2/train/images/20220531_111001_jpg.rf.0d27aa5ca083d9641946465b3484837e.jpg: ignoring corrupt image/label: labels mix segment and detection rows
# train: /content/EcoVision-2/train/images/20220531_111001_jpg.rf.0fa8496cdc3d864416a698e4575eead1.jpg: ignoring corrupt image/label: labels mix segment and detection rows
# train: /content/EcoVision-2/train/images/20220531_111001_jpg.rf.2115fb71f3793ef20a6cb7c0434396ea.jpg: ignoring corrupt image/label: labels mix segment and detection rows
# train: /content/EcoVision-2/train/images/20220531_111001_jpg.rf.3434f3bf6e172f66a5388d4c5e954ef3.jpg: ignoring corrupt image/label: labels mix segment and detection rows
# train: /content/EcoVision-2/train/images/20220531_111001_jpg.rf.3d7d0d4cbe17c53994e88d98f640471a.jpg: ignoring corrupt image/label: labels mix segment and detection rows
# train: /content/EcoVision-2/train/images/20220531_111001_jpg.rf.3f43b0d2aa10c96575c5a2413575b014.jpg: ignoring corrupt image/label: labels mix segment and detection rows
# train: /content/EcoVision-2/train/images/20220531_111001_jpg.rf.acaeddef10ef11b2cd2281f8971c7c1f.jpg: ignoring corrupt image/label: labels mix segment and detection rows
# train: /content/EcoVision-2/train/images/20220531_111001_jpg.rf.e727a7ceb857cf9fd0d62f5567ba6071.jpg: ignoring corrupt image/label: labels mix segment and detection rows
# train: /content/EcoVision-2/train/images/20220531_111001_jpg.rf.e979774c1fba5bc439710862a20c3576.jpg: ignoring corrupt image/label: labels mix segment and detection rows
# train: /content/EcoVision-2/train/images/20220531_111813_jpg.rf.52b4be8436edc5cc6d79a87688aa9437.jpg: ignoring corrupt image/label: labels mix segment and detection rows
# train: /content/EcoVision-2/train/images/20220531_111813_jpg.rf.9b6c29da9e3e07bd0c313aabed6bbbf7.jpg: ignoring corrupt image/label: labels mix segment and detection rows
# train: /content/EcoVision-2/train/images/20220531_111813_jpg.rf.a7e0b0eaf322ba97127e63ff8640f5fe.jpg: ignoring corrupt image/label: labels mix segment and detection rows
# train: /content/EcoVision-2/train/images/20220531_111827_jpg.rf.1210abd69405b3d3d43c697c39c69a01.jpg: ignoring corrupt image/label: labels mix segment and detection rows
# train: /content/EcoVision-2/train/images/20220531_111827_jpg.rf.1e025e89e972fa5093532d18a85342ca.jpg: ignoring corrupt image/label: labels mix segment and detection rows
# train: /content/EcoVision-2/train/images/20220531_111827_jpg.rf.9cde9418a3bfcb53ac308cbd9a6236b3.jpg: ignoring corrupt image/label: labels mix segment and detection rows
# train: /content/EcoVision-2/train/images/20220531_111827_jpg.rf.9cdffa57447c1cc8c994c20268630d74.jpg: ignoring corrupt image/label: labels mix segment and detection rows
# train: /content/EcoVision-2/train/images/20220531_111827_jpg.rf.d9a7d328a6e136f0de76bc3da175d97a.jpg: ignoring corrupt image/label: labels mix segment and detection rows
# train: /content/EcoVision-2/train/images/20220531_111827_jpg.rf.ef9fefd7dc65765d04abc80d66bb7498.jpg: ignoring corrupt image/label: labels mix segment and detection rows
# train: /content/EcoVision-2/train/images/20220531_113341_jpg.rf.5b09d5e8a4971885b0e6335eaec467f4.jpg: ignoring corrupt image/label: labels mix segment and detection rows
# train: /content/EcoVision-2/train/images/20220531_113341_jpg.rf.5d72508c3ef49942d5d7341429e4e358.jpg: ignoring corrupt image/label: labels mix segment and detection rows
# train: /content/EcoVision-2/train/images/20220531_113341_jpg.rf.c853303fbb8d3c5fd846910dffa1d6cb.jpg: ignoring corrupt image/label: labels mix segment and detection rows
# train: /content/EcoVision-2/train/images/20220615_093237_jpg.rf.1a232cbd36d8b712dea349e1aac56d8e.jpg: ignoring corrupt image/label: labels mix segment and detection rows
# train: /content/EcoVision-2/train/images/20220615_093237_jpg.rf.394b1895275ca4572b01cbe47f861597.jpg: ignoring corrupt image/label: labels mix segment and detection rows
# train: /content/EcoVision-2/train/images/20220615_093237_jpg.rf.d5252465188d64e3c3717601b2752e9d.jpg: ignoring corrupt image/label: labels mix segment and detection rows
# train: /content/EcoVision-2/train/images/20220615_093655_jpg.rf.15fcf2e0b1df1b404f188a3db5c586c9.jpg: ignoring corrupt image/label: labels mix segment and detection rows
# train: /content/EcoVision-2/train/images/20220615_093655_jpg.rf.3a32d3a578ac494619ed8a1f24776d82.jpg: ignoring corrupt image/label: labels mix segment and detection rows
# train: /content/EcoVision-2/train/images/20220615_093655_jpg.rf.40e1babf5ea0787cf66e3120f61b42fb.jpg: ignoring corrupt image/label: labels mix segment and detection rows
# train: /content/EcoVision-2/train/images/20220615_093655_jpg.rf.4343546be66337757098af1f80f7972d.jpg: ignoring corrupt image/label: labels mix segment and detection rows
# train: /content/EcoVision-2/train/images/20220615_093655_jpg.rf.81eb60157382ec24d1a0ffc3c8f0e7db.jpg: ignoring corrupt image/label: labels mix segment and detection rows
# train: /content/EcoVision-2/train/images/20220615_093655_jpg.rf.871c7067b578c583eeb57f92ff052725.jpg: ignoring corrupt image/label: labels mix segment and detection rows
# train: /content/EcoVision-2/train/images/20220615_093655_jpg.rf.8971cb8cd67a6289a934e8d9d4e39b33.jpg: ignoring corrupt image/label: labels mix segment and detection rows
# train: /content/EcoVision-2/train/images/20220615_093655_jpg.rf.961b3bc447afceb61942d94640aa34f7.jpg: ignoring corrupt image/label: labels mix segment and detection rows
# train: /content/EcoVision-2/train/images/20220615_093655_jpg.rf.f2fb987e3b11e8142e7a80aebfabd8a1.jpg: ignoring corrupt image/label: labels mix segment and detection rows
# train: /content/EcoVision-2/train/images/20220615_093855_jpg.rf.2cbcd342ab418ff90446edada0f8b870.jpg: ignoring corrupt image/label: labels mix segment and detection rows
# train: /content/EcoVision-2/train/images/20220615_093855_jpg.rf.9bfa3099f4534d76e15d62a2a855f546.jpg: ignoring corrupt image/label: labels mix segment and detection rows
# train: /content/EcoVision-2/train/images/20220615_093855_jpg.rf.c51563841f65d875dd9c884aea33f216.jpg: ignoring corrupt image/label: labels mix segment and detection rows
# train: /content/EcoVision-2/train/images/20220615_094208_jpg.rf.6ecba3b4ba47595b745b90ef1f098bd2.jpg: ignoring corrupt image/label: labels mix segment and detection rows
# train: /content/EcoVision-2/train/images/20220615_094208_jpg.rf.7b65c1b8a0f3e460b371d2b6cd408dca.jpg: ignoring corrupt image/label: labels mix segment and detection rows
# train: /content/EcoVision-2/train/images/20220615_094208_jpg.rf.9183aa241dda12d5a61f0b0931d3dd2e.jpg: ignoring corrupt image/label: labels mix segment and detection rows
# train: /content/EcoVision-2/train/images/20220615_094608_jpg.rf.0b5b99f1627093378ec7639f1437a187.jpg: ignoring corrupt image/label: labels mix segment and detection rows
# train: /content/EcoVision-2/train/images/20220615_094608_jpg.rf.428caf8284be9b3ecbcd7346848ef758.jpg: ignoring corrupt image/label: labels mix segment and detection rows
# train: /content/EcoVision-2/train/images/20220615_094608_jpg.rf.4a694ac0370e1bdca03c08fb8222462b.jpg: ignoring corrupt image/label: labels mix segment and detection rows
# train: /content/EcoVision-2/train/images/20220615_094612_jpg.rf.3032f48496f24c3d5ebf83939485f8c2.jpg: ignoring corrupt image/label: labels mix segment and detection rows
# train: /content/EcoVision-2/train/images/20220615_094612_jpg.rf.813d2e03f6c9933532a2293c1735037d.jpg: ignoring corrupt image/label: labels mix segment and detection rows
# train: /content/EcoVision-2/train/images/20220615_094612_jpg.rf.983c3f24f508120582417b33046c76a9.jpg: ignoring corrupt image/label: labels mix segment and detection rows
# train: /content/EcoVision-2/train/images/20220615_094612_jpg.rf.a3a6588c4f8241e279bc5838d74bd3de.jpg: ignoring corrupt image/label: labels mix segment and detection rows
# train: /content/EcoVision-2/train/images/20220615_094612_jpg.rf.b0b1fbd2607d342163871f5a57ebbd26.jpg: ignoring corrupt image/label: labels mix segment and detection rows
# train: /content/EcoVision-2/train/images/20220615_094612_jpg.rf.db95264ed4f08f1a9a89a755124c0ebb.jpg: ignoring corrupt image/label: labels mix segment and detection rows
# train: /content/EcoVision-2/train/images/20220615_094728_jpg.rf.21542556179527ae975df5e194f2ce30.jpg: ignoring corrupt image/label: labels mix segment and detection rows
# train: /content/EcoVision-2/train/images/20220615_094728_jpg.rf.a3afb162de56706a2718647361903059.jpg: ignoring corrupt image/label: labels mix segment and detection rows
# train: /content/EcoVision-2/train/images/20220615_094728_jpg.rf.e52e15fb0d2b2ba05d8323ed38ce3b6d.jpg: ignoring corrupt image/label: labels mix segment and detection rows
# train: /content/EcoVision-2/train/images/20220615_095122_jpg.rf.1e1c22eeb4943abcdc94d45a9c207748.jpg: ignoring corrupt image/label: labels mix segment and detection rows
# train: /content/EcoVision-2/train/images/20220615_095122_jpg.rf.730a219ae32e46ae004ec99c1db2a3df.jpg: ignoring corrupt image/label: labels mix segment and detection rows
# train: /content/EcoVision-2/train/images/20220615_095122_jpg.rf.7f5d4fd7acd43662974c13aa55833d2d.jpg: ignoring corrupt image/label: labels mix segment and detection rows
# train: /content/EcoVision-2/train/images/20220615_095122_jpg.rf.8534bfea7b32cba56cffcf15150fcc32.jpg: ignoring corrupt image/label: labels mix segment and detection rows
# train: /content/EcoVision-2/train/images/20220615_095122_jpg.rf.a32b61930144dfc3b22c865dfe29264b.jpg: ignoring corrupt image/label: labels mix segment and detection rows
# train: /content/EcoVision-2/train/images/20220615_095122_jpg.rf.c8d8d0da00ceb70d8b680cd665df8b4e.jpg: ignoring corrupt image/label: labels mix segment and detection rows
# train: /content/EcoVision-2/train/images/20220615_142417_jpg.rf.00c98c422eb81b2aafe54d10a50e3f18.jpg: ignoring corrupt image/label: labels mix segment and detection rows
# train: /content/EcoVision-2/train/images/20220615_142417_jpg.rf.1170256a0c04fef128370884835df461.jpg: ignoring corrupt image/label: labels mix segment and detection rows
# train: /content/EcoVision-2/train/images/20220615_142417_jpg.rf.e1849886d8c0f9425308098365db921d.jpg: ignoring corrupt image/label: labels mix segment and detection rows
# train: /content/EcoVision-2/train/images/20220615_142531_jpg.rf.409f6f6a3d2d7bc29c6b673865fe09cd.jpg: ignoring corrupt image/label: labels mix segment and detection rows
# train: /content/EcoVision-2/train/images/20220615_142531_jpg.rf.5cb045edc014335e1fa89ffc219e3c61.jpg: ignoring corrupt image/label: labels mix segment and detection rows
# train: /content/EcoVision-2/train/images/20220615_142531_jpg.rf.e04c8a021eaf8bbdaefd6e9522e94039.jpg: ignoring corrupt image/label: labels mix segment and detection rows
# train: /content/EcoVision-2/train/images/20220615_142626_jpg.rf.4b82fb49665bd766e9587e133071a371.jpg: ignoring corrupt image/label: labels mix segment and detection rows
# train: /content/EcoVision-2/train/images/20220615_142626_jpg.rf.e275fd539843aa2f219d03fe69fb9c63.jpg: ignoring corrupt image/label: labels mix segment and detection rows
# train: /content/EcoVision-2/train/images/20220615_142626_jpg.rf.fcdc9a60e6cd717ff3568d699281db76.jpg: ignoring corrupt image/label: labels mix segment and detection rows
# train: /content/EcoVision-2/train/images/20220615_142720_jpg.rf.1be06a0f71d9f88e0f7e220e1e6081a5.jpg: ignoring corrupt image/label: labels mix segment and detection rows
# train: /content/EcoVision-2/train/images/20220615_142720_jpg.rf.e8e5a9668f12d52bc211488fa3d36495.jpg: ignoring corrupt image/label: labels mix segment and detection rows
# train: /content/EcoVision-2/train/images/20220615_142720_jpg.rf.f62f07982bab46cb4f388e94b2fdd281.jpg: ignoring corrupt image/label: labels mix segment and detection rows
# train: /content/EcoVision-2/train/images/20220615_143516_jpg.rf.bc2a2f397249c008fb4821f462d2b33d.jpg: ignoring corrupt image/label: labels mix segment and detection rows
# train: /content/EcoVision-2/train/images/20220615_143516_jpg.rf.c591f5fe6c2e13a7db31b682566902e1.jpg: ignoring corrupt image/label: labels mix segment and detection rows
# train: /content/EcoVision-2/train/images/20220615_143516_jpg.rf.daf783b946c2e54a00e51fce6942580c.jpg: ignoring corrupt image/label: labels mix segment and detection rows
# train: /content/EcoVision-2/train/images/20220615_143528_jpg.rf.04577fa2c02af116a941a5bda32ce8b7.jpg: ignoring corrupt image/label: labels mix segment and detection rows
# train: /content/EcoVision-2/train/images/20220615_143528_jpg.rf.0480d94b411b14d727986302b1bef237.jpg: ignoring corrupt image/label: labels mix segment and detection rows
# train: /content/EcoVision-2/train/images/20220615_143528_jpg.rf.260b86f1672e66bdef05646654d2a0a7.jpg: ignoring corrupt image/label: labels mix segment and detection rows
# train: /content/EcoVision-2/train/images/20220615_143528_jpg.rf.341546dcfe7f43c46051b5cd12b86c8d.jpg: ignoring corrupt image/label: labels mix segment and detection rows
# train: /content/EcoVision-2/train/images/20220615_143528_jpg.rf.3c642484cd5561fefe2685e19ed14914.jpg: ignoring corrupt image/label: labels mix segment and detection rows
# train: /content/EcoVision-2/train/images/20220615_143528_jpg.rf.74f866b47f8c7ce941b98c00166ab94c.jpg: ignoring corrupt image/label: labels mix segment and detection rows
# train: /content/EcoVision-2/train/images/20220615_143641_jpg.rf.0a4b3ca3497460468e943929c9e7484a.jpg: ignoring corrupt image/label: labels mix segment and detection rows
# train: /content/EcoVision-2/train/images/20220615_143641_jpg.rf.2d20847f1f29f0c5c183e92ea2b7d7e7.jpg: ignoring corrupt image/label: labels mix segment and detection rows
# train: /content/EcoVision-2/train/images/20220615_143641_jpg.rf.be4a9b20e33fb46ff06a44284015f6b1.jpg: ignoring corrupt image/label: labels mix segment and detection rows
# train: /content/EcoVision-2/train/images/20220615_143912_jpg.rf.2a983c58bd484c47ed7d37c170d88caa.jpg: ignoring corrupt image/label: labels mix segment and detection rows
# train: /content/EcoVision-2/train/images/20220615_143912_jpg.rf.6d35c49371b884c06722f04d0b6533ab.jpg: ignoring corrupt image/label: labels mix segment and detection rows
# train: /content/EcoVision-2/train/images/20220615_143912_jpg.rf.fdc2fe940b98e8adb7f70132716642c5.jpg: ignoring corrupt image/label: labels mix segment and detection rows
# train: /content/EcoVision-2/train/images/20220615_144113_jpg.rf.49618eca71212fb6a3bd1ad1cc14a94d.jpg: ignoring corrupt image/label: labels mix segment and detection rows
# train: /content/EcoVision-2/train/images/20220615_144113_jpg.rf.9f18faf957492578becd69971e687507.jpg: ignoring corrupt image/label: labels mix segment and detection rows
# train: /content/EcoVision-2/train/images/20220615_144113_jpg.rf.e466c4ef2796d479c35b0ac838a16ee4.jpg: ignoring corrupt image/label: labels mix segment and detection rows
# train: /content/EcoVision-2/train/images/20220615_144133_jpg.rf.a478c58228e475ccaf6a4a0ab2487e43.jpg: ignoring corrupt image/label: labels mix segment and detection rows
# train: /content/EcoVision-2/train/images/20220615_144133_jpg.rf.adfea0d28a8f4a3be767b080a5f85ebc.jpg: ignoring corrupt image/label: labels mix segment and detection rows
# train: /content/EcoVision-2/train/images/20220615_144133_jpg.rf.cb279917c5d449d91bc275280713408c.jpg: ignoring corrupt image/label: labels mix segment and detection rows
# train: /content/EcoVision-2/train/images/20220615_144820_jpg.rf.56e666e2e8362f39c92b6aa8c6e87e33.jpg: ignoring corrupt image/label: labels mix segment and detection rows
# train: /content/EcoVision-2/train/images/20220615_144820_jpg.rf.66119c10edfecafeb4849220f850c9b3.jpg: ignoring corrupt image/label: labels mix segment and detection rows
# train: /content/EcoVision-2/train/images/20220615_144820_jpg.rf.789eeef0a80f9babf1383508ed10ee22.jpg: ignoring corrupt image/label: labels mix segment and detection rows
# train: /content/EcoVision-2/train/images/20220615_145038_jpg.rf.07422310d217e7772d6effaaa4c17165.jpg: ignoring corrupt image/label: labels mix segment and detection rows
# train: /content/EcoVision-2/train/images/20220615_145038_jpg.rf.157972c12555391fd0289fbf95221966.jpg: ignoring corrupt image/label: labels mix segment and detection rows
# train: /content/EcoVision-2/train/images/20220615_145038_jpg.rf.c53516ee1a021bf7da4c1a66dffa2972.jpg: ignoring corrupt image/label: labels mix segment and detection rows
# train: /content/EcoVision-2/train/images/20220615_145049_jpg.rf.30bd20c18f50ebe185200b8ad4fe9f6c.jpg: ignoring corrupt image/label: labels mix segment and detection rows
# train: /content/EcoVision-2/train/images/20220615_145049_jpg.rf.38dc41539263711aca8bcad3bc3ab50e.jpg: ignoring corrupt image/label: labels mix segment and detection rows
# train: /content/EcoVision-2/train/images/20220615_145049_jpg.rf.623dc0505f1a2e8069f35bf3dd873bfd.jpg: ignoring corrupt image/label: labels mix segment and detection rows
# train: /content/EcoVision-2/train/images/20220615_145049_jpg.rf.b1b31333272bfaf6dd312f7a9b96fb8d.jpg: ignoring corrupt image/label: labels mix segment and detection rows
# train: /content/EcoVision-2/train/images/20220615_145049_jpg.rf.dd8a6dfe9a35b19b38582c0afb875658.jpg: ignoring corrupt image/label: labels mix segment and detection rows
# train: /content/EcoVision-2/train/images/20220615_145049_jpg.rf.ea252b01fa1a254ab899297515860296.jpg: ignoring corrupt image/label: labels mix segment and detection rows
# train: /content/EcoVision-2/train/images/20220615_150016_jpg.rf.5265ff26760e770fa09764441acff8f9.jpg: ignoring corrupt image/label: labels mix segment and detection rows
# train: /content/EcoVision-2/train/images/20220615_150016_jpg.rf.77b02c55c50279a6718e0d29c7b3b747.jpg: ignoring corrupt image/label: labels mix segment and detection rows
# train: /content/EcoVision-2/train/images/20220615_150016_jpg.rf.dfd4f8b646ab2c860482dd267cc0571b.jpg: ignoring corrupt image/label: labels mix segment and detection rows
# train: /content/EcoVision-2/train/images/20220615_150032_jpg.rf.2a1637b07927d4a990e893a9bf75a6e9.jpg: ignoring corrupt image/label: labels mix segment and detection rows
# train: /content/EcoVision-2/train/images/20220615_150032_jpg.rf.46f32beb721465e47e219677f18db4d4.jpg: ignoring corrupt image/label: labels mix segment and detection rows
# train: /content/EcoVision-2/train/images/20220615_150032_jpg.rf.9c992df707a41ddd42601e1eb6c1f6d8.jpg: ignoring corrupt image/label: labels mix segment and detection rows
# train: /content/EcoVision-2/train/images/20220615_150409_jpg.rf.0e6fc6b3a3d6df1843123bc9579c7dcc.jpg: ignoring corrupt image/label: labels mix segment and detection rows
# train: /content/EcoVision-2/train/images/20220615_150409_jpg.rf.1aeaaca40a626788dfac149b512f70df.jpg: ignoring corrupt image/label: labels mix segment and detection rows
# train: /content/EcoVision-2/train/images/20220615_150409_jpg.rf.8934577f1ea8c315c86d0747e1460645.jpg: ignoring corrupt image/label: labels mix segment and detection rows
# train: /content/EcoVision-2/train/images/20220615_150523_jpg.rf.64e2d56d22acb406cd41c9d2c4bb6e26.jpg: ignoring corrupt image/label: labels mix segment and detection rows
# train: /content/EcoVision-2/train/images/20220615_150523_jpg.rf.7f5c1042fffbc79e24be2d5d0b83a267.jpg: ignoring corrupt image/label: labels mix segment and detection rows
# train: /content/EcoVision-2/train/images/20220615_150523_jpg.rf.8db0bae38c9e6ce4926372909700cab9.jpg: ignoring corrupt image/label: labels mix segment and detection rows
# train: /content/EcoVision-2/train/images/20220615_150523_jpg.rf.9b3bbbd46023ab56eff2d7e52dbba36d.jpg: ignoring corrupt image/label: labels mix segment and detection rows
# train: /content/EcoVision-2/train/images/20220615_150523_jpg.rf.d41fd229a2ea0a714d0ec99676cabdf3.jpg: ignoring corrupt image/label: labels mix segment and detection rows
# train: /content/EcoVision-2/train/images/20220615_150523_jpg.rf.eecce6d16b5c23eb25a50c24e217dbfe.jpg: ignoring corrupt image/label: labels mix segment and detection rows
# train: /content/EcoVision-2/train/images/20220615_150532_jpg.rf.64e05b4168899f5cdf263f088eb7ee78.jpg: ignoring corrupt image/label: labels mix segment and detection rows
# train: /content/EcoVision-2/train/images/20220615_150532_jpg.rf.79c8c45d7ca3adfd24d5b25b0a13ecdb.jpg: ignoring corrupt image/label: labels mix segment and detection rows
# train: /content/EcoVision-2/train/images/20220615_150532_jpg.rf.879a5c3c30d94f03b5608094f58b098c.jpg: ignoring corrupt image/label: labels mix segment and detection rows
# train: /content/EcoVision-2/train/images/20220615_150542_jpg.rf.4e51b0c917bd01afb09ece455606ed37.jpg: ignoring corrupt image/label: labels mix segment and detection rows
# train: /content/EcoVision-2/train/images/20220615_150542_jpg.rf.5f3cb98af2a6d7e64989d2421f96dbfc.jpg: ignoring corrupt image/label: labels mix segment and detection rows
# train: /content/EcoVision-2/train/images/20220615_150542_jpg.rf.77ac6743d7f0036413d5bcfcb063fe26.jpg: ignoring corrupt image/label: labels mix segment and detection rows
# train: /content/EcoVision-2/train/images/20220615_150542_jpg.rf.8678b06e5149caf4b1dce46e2cfa61f6.jpg: ignoring corrupt image/label: labels mix segment and detection rows
# train: /content/EcoVision-2/train/images/20220615_150542_jpg.rf.a667b4cc62f9dac91897327b2969fa03.jpg: ignoring corrupt image/label: labels mix segment and detection rows
# train: /content/EcoVision-2/train/images/20220615_150542_jpg.rf.ce14dd7db5b3da33be103fc3cf31de7d.jpg: ignoring corrupt image/label: labels mix segment and detection rows
# train: /content/EcoVision-2/train/images/20220615_150555_jpg.rf.500105944f476d076f5e3960fdcc5e21.jpg: ignoring corrupt image/label: labels mix segment and detection rows
# train: /content/EcoVision-2/train/images/20220615_150555_jpg.rf.cbc7e921b9958d84bc3a01b7cca11532.jpg: ignoring corrupt image/label: labels mix segment and detection rows
# train: /content/EcoVision-2/train/images/20220615_150555_jpg.rf.ec0a7ccb4e45ee2225afdcd3be2cb94c.jpg: ignoring corrupt image/label: labels mix segment and detection rows
# train: /content/EcoVision-2/train/images/20220615_151033_jpg.rf.1b5ab649592b2d49d9edf69e986b26e0.jpg: ignoring corrupt image/label: labels mix segment and detection rows
# train: /content/EcoVision-2/train/images/20220615_151033_jpg.rf.1c47055045caf2cd0877ae662f50606c.jpg: ignoring corrupt image/label: labels mix segment and detection rows
# train: /content/EcoVision-2/train/images/20220615_151033_jpg.rf.6c46435bccf58bd8a39ca2e9cdd33d32.jpg: ignoring corrupt image/label: labels mix segment and detection rows
# train: /content/EcoVision-2/train/images/20220615_151033_jpg.rf.8021415241094dae9f8c2ddbb057e4e8.jpg: ignoring corrupt image/label: labels mix segment and detection rows
# train: /content/EcoVision-2/train/images/20220615_151033_jpg.rf.c8df1eb3558fe89a42f67bf5d8ed2371.jpg: ignoring corrupt image/label: labels mix segment and detection rows
# train: /content/EcoVision-2/train/images/20220615_151033_jpg.rf.fba11376276f7748af56278f8f1e1106.jpg: ignoring corrupt image/label: labels mix segment and detection rows
# train: /content/EcoVision-2/train/images/20220615_151042_jpg.rf.306d1c9230f1eee11acfd233cb254b52.jpg: ignoring corrupt image/label: labels mix segment and detection rows
# train: /content/EcoVision-2/train/images/20220615_151042_jpg.rf.7d3b3f6e2cba51d3c922bf550d7e3a45.jpg: ignoring corrupt image/label: labels mix segment and detection rows
# train: /content/EcoVision-2/train/images/20220615_151042_jpg.rf.9f2486e158f118aefdcb0384c18c25e7.jpg: ignoring corrupt image/label: labels mix segment and detection rows
# train: /content/EcoVision-2/train/images/20220615_151042_jpg.rf.c9acf558673fe083d1c01362c32a06d9.jpg: ignoring corrupt image/label: labels mix segment and detection rows
# train: /content/EcoVision-2/train/images/20220615_151042_jpg.rf.d198473aba5f881add44158df2d1b7e6.jpg: ignoring corrupt image/label: labels mix segment and detection rows
# train: /content/EcoVision-2/train/images/20220615_151042_jpg.rf.f1d09525456b267bed89ff10d9028552.jpg: ignoring corrupt image/label: labels mix segment and detection rows
# train: /content/EcoVision-2/train/images/20220615_151300_jpg.rf.08fb6ae33c94ed173238aa235f01bb9d.jpg: ignoring corrupt image/label: labels mix segment and detection rows
# train: /content/EcoVision-2/train/images/20220615_151300_jpg.rf.7e189b5231f91b5a7cc49177028b32e5.jpg: ignoring corrupt image/label: labels mix segment and detection rows
# train: /content/EcoVision-2/train/images/20220615_151300_jpg.rf.80fb2f42efb7601fac2b9fad771fdc4a.jpg: ignoring corrupt image/label: labels mix segment and detection rows
# train: /content/EcoVision-2/train/images/20220615_151300_jpg.rf.840148300296d9ec99918e7baea8f4d8.jpg: ignoring corrupt image/label: labels mix segment and detection rows
# train: /content/EcoVision-2/train/images/20220615_151300_jpg.rf.a24115bf9ab41b2411e3152f2c0147ed.jpg: ignoring corrupt image/label: labels mix segment and detection rows
# train: /content/EcoVision-2/train/images/20220615_151300_jpg.rf.dee2da23981b4f801471a35b3783e0a8.jpg: ignoring corrupt image/label: labels mix segment and detection rows
# train: /content/EcoVision-2/train/images/IMG20220531142530_jpg.rf.3abf7d55f818a3e97c92041828af5c1d.jpg: ignoring corrupt image/label: labels mix segment and detection rows
# train: /content/EcoVision-2/train/images/IMG20220531142530_jpg.rf.4ac4217805554d86e0f2753b7fd8e5f8.jpg: ignoring corrupt image/label: labels mix segment and detection rows
# train: /content/EcoVision-2/train/images/IMG20220531142530_jpg.rf.b8e87b6ba0c3d2fc31b2e709481c0d34.jpg: ignoring corrupt image/label: labels mix segment and detection rows
# train: /content/EcoVision-2/train/images/IMG20220531144817_jpg.rf.042a55908f4575d91ea0b5a83d58a7fc.jpg: ignoring corrupt image/label: labels mix segment and detection rows
# train: /content/EcoVision-2/train/images/IMG20220531144817_jpg.rf.0a41f7c82223823c6ebef8428092172b.jpg: ignoring corrupt image/label: labels mix segment and detection rows
# train: /content/EcoVision-2/train/images/IMG20220531144817_jpg.rf.7a13b4aab6abd3ee6bb54594a588305a.jpg: ignoring corrupt image/label: labels mix segment and detection rows
# train: /content/EcoVision-2/train/images/IMG_20240304_094832_jpg.rf.b01ea7faf1d8cd5923cfce854c0ae232.jpg: ignoring corrupt image/label: labels mix segment and detection rows
# train: /content/EcoVision-2/train/images/a000088_JPG_jpg.rf.27a17d7ea8da1438b4e366b1985d7be4.jpg: ignoring corrupt image/label: labels mix segment and detection rows
# train: /content/EcoVision-2/train/images/a000088_JPG_jpg.rf.37aadc7d96c796345d6e10a25313a027.jpg: ignoring corrupt image/label: labels mix segment and detection rows
# train: /content/EcoVision-2/train/images/a000088_JPG_jpg.rf.f717da1d62fdb918b28fde0104a30c3f.jpg: ignoring corrupt image/label: labels mix segment and detection rows
# train: /content/EcoVision-2/train/images/cup2_4_jpg.rf.223921ca037597d92a1fe9e3e7c60c9d.jpg: ignoring corrupt image/label: labels mix segment and detection rows
# train: /content/EcoVision-2/train/images/cup2_5_jpg.rf.aa3f92a7a366758009d6b1031b21308d.jpg: ignoring corrupt image/label: labels mix segment and detection rows
# train: /content/EcoVision-2/train/images/frame0_jpg.rf.203ef03ccc9566cba39a444cd088d0d0.jpg: ignoring corrupt image/label: labels mix segment and detection rows
# train: /content/EcoVision-2/train/images/frame0_jpg.rf.6504abe3fc809289709c430137a81637.jpg: ignoring corrupt image/label: labels mix segment and detection rows
# train: /content/EcoVision-2/train/images/frame0_jpg.rf.d592a0718cda4b3280c8f5d93ead6efc.jpg: ignoring corrupt image/label: labels mix segment and detection rows
# train: /content/EcoVision-2/train/images/frame0_jpg.rf.e690cec235589e7ad49c055abed095a6.jpg: ignoring corrupt image/label: labels mix segment and detection rows
# train: /content/EcoVision-2/train/images/frame0_jpg.rf.f04a2811e5cb23fc30b72207d38984b2.jpg: ignoring corrupt image/label: labels mix segment and detection rows
# train: /content/EcoVision-2/train/images/frame0_jpg.rf.fc186ff463978e3e3b8bce5fc397733c.jpg: ignoring corrupt image/label: labels mix segment and detection rows
# train: /content/EcoVision-2/train/images/frame10_jpg.rf.3824e12f9cc7d0c52dcd01ac55dc6f9f.jpg: ignoring corrupt image/label: labels mix segment and detection rows
# train: /content/EcoVision-2/train/images/frame10_jpg.rf.4f72329004a3d37f5b6635c978e16125.jpg: ignoring corrupt image/label: labels mix segment and detection rows
# train: /content/EcoVision-2/train/images/frame10_jpg.rf.90a34789b661fad6043e71bb75714a89.jpg: ignoring corrupt image/label: labels mix segment and detection rows
# train: /content/EcoVision-2/train/images/frame11_jpg.rf.038761b5241cafabe4252fad9e35f936.jpg: ignoring corrupt image/label: labels mix segment and detection rows
# train: /content/EcoVision-2/train/images/frame11_jpg.rf.05edba894c92d0c29a56d8491e14a0ac.jpg: ignoring corrupt image/label: labels mix segment and detection rows
# train: /content/EcoVision-2/train/images/frame11_jpg.rf.2bb6e7ed1c316ba8ee52c33586e20935.jpg: ignoring corrupt image/label: labels mix segment and detection rows
# train: /content/EcoVision-2/train/images/frame11_jpg.rf.36e63b8f85db95063069912fab67fdc0.jpg: ignoring corrupt image/label: labels mix segment and detection rows
# train: /content/EcoVision-2/train/images/frame11_jpg.rf.438e50cb4802e800f8fb5a8817fc686f.jpg: ignoring corrupt image/label: labels mix segment and detection rows
# train: /content/EcoVision-2/train/images/frame11_jpg.rf.5a9daff0d77e95bd15dca96426c1bb1e.jpg: ignoring corrupt image/label: labels mix segment and detection rows
# train: /content/EcoVision-2/train/images/frame11_jpg.rf.7da3a0978dc61f5e322809b6098c2a49.jpg: ignoring corrupt image/label: labels mix segment and detection rows
# train: /content/EcoVision-2/train/images/frame11_jpg.rf.82cd84f8a88606557d16d84733ee4e2f.jpg: ignoring corrupt image/label: labels mix segment and detection rows
# train: /content/EcoVision-2/train/images/frame11_jpg.rf.8c18cbf8ff86f63fdcc85d2a71bf382a.jpg: ignoring corrupt image/label: labels mix segment and detection rows
# train: /content/EcoVision-2/train/images/frame11_jpg.rf.8c2ad24218322e6ee4f608b47ad02e24.jpg: ignoring corrupt image/label: labels mix segment and detection rows
# train: /content/EcoVision-2/train/images/frame11_jpg.rf.a217bdbec24c2c81c4caff9dc6a6b655.jpg: ignoring corrupt image/label: labels mix segment and detection rows
# train: /content/EcoVision-2/train/images/frame11_jpg.rf.a8a7a032a9524efb016ce5016ea723d0.jpg: ignoring corrupt image/label: labels mix segment and detection rows
# train: /content/EcoVision-2/train/images/frame11_jpg.rf.c8f20557511ac2dfaa8b693b40e4713e.jpg: ignoring corrupt image/label: labels mix segment and detection rows
# train: /content/EcoVision-2/train/images/frame11_jpg.rf.ed7103247dd75cc8292d2b7a7594b705.jpg: ignoring corrupt image/label: labels mix segment and detection rows
# train: /content/EcoVision-2/train/images/frame11_jpg.rf.fdce48a52e4ced8a84cf4f9a3fab55f1.jpg: ignoring corrupt image/label: labels mix segment and detection rows
# train: /content/EcoVision-2/train/images/frame12_jpg.rf.038b6c043c33fc4d88171aa58135557c.jpg: ignoring corrupt image/label: labels mix segment and detection rows
# train: /content/EcoVision-2/train/images/frame12_jpg.rf.07262b1f505aa307608b5e3b4ed9c488.jpg: ignoring corrupt image/label: labels mix segment and detection rows
# train: /content/EcoVision-2/train/images/frame12_jpg.rf.3a70c163f84eca01f9ac133e162b170a.jpg: ignoring corrupt image/label: labels mix segment and detection rows
# train: /content/EcoVision-2/train/images/frame12_jpg.rf.3b60f34c45d5fdfa0b9f7a5f5fba16d7.jpg: ignoring corrupt image/label: labels mix segment and detection rows
# train: /content/EcoVision-2/train/images/frame12_jpg.rf.46153e1d4b67afff2c1a5f0fe7dfea07.jpg: ignoring corrupt image/label: labels mix segment and detection rows
# train: /content/EcoVision-2/train/images/frame12_jpg.rf.475bee4ea114daabc800dc07714e7630.jpg: ignoring corrupt image/label: labels mix segment and detection rows
# train: /content/EcoVision-2/train/images/frame12_jpg.rf.7695a3390feccc822c2d12bb1a649e0c.jpg: ignoring corrupt image/label: labels mix segment and detection rows
# train: /content/EcoVision-2/train/images/frame12_jpg.rf.9b16b58eabb1be32c26c281b28844ffa.jpg: ignoring corrupt image/label: labels mix segment and detection rows
# train: /content/EcoVision-2/train/images/frame12_jpg.rf.b6a31d38e32dcfb06563430df2fdc01e.jpg: ignoring corrupt image/label: labels mix segment and detection rows
# train: /content/EcoVision-2/train/images/frame12_jpg.rf.b6ce25f18e673fd31b250a8c406e0022.jpg: ignoring corrupt image/label: labels mix segment and detection rows
# train: /content/EcoVision-2/train/images/frame12_jpg.rf.cbc7a130fc49e2657f68facaa09ad8ed.jpg: ignoring corrupt image/label: labels mix segment and detection rows
# train: /content/EcoVision-2/train/images/frame12_jpg.rf.d264f26abd82d9d20ea78973ad492602.jpg: ignoring corrupt image/label: labels mix segment and detection rows
# train: /content/EcoVision-2/train/images/frame13_jpg.rf.105f5741097151895a0d632db94e4832.jpg: ignoring corrupt image/label: labels mix segment and detection rows
# train: /content/EcoVision-2/train/images/frame13_jpg.rf.5db6a1eeba32fa316ed40614e1e74c35.jpg: ignoring corrupt image/label: labels mix segment and detection rows
# train: /content/EcoVision-2/train/images/frame13_jpg.rf.cd7b25fe72bcef52550f1a69f33dcadd.jpg: ignoring corrupt image/label: labels mix segment and detection rows
# train: /content/EcoVision-2/train/images/frame13_jpg.rf.d3b9a0d2681aafa79b0dc2876a1e6112.jpg: ignoring corrupt image/label: labels mix segment and detection rows
# train: /content/EcoVision-2/train/images/frame13_jpg.rf.e1cf0cbce4cb15a4d315457421f8e04c.jpg: ignoring corrupt image/label: labels mix segment and detection rows
# train: /content/EcoVision-2/train/images/frame14_jpg.rf.3dcd4980fc850953dd18c8c0dae80e0b.jpg: ignoring corrupt image/label: labels mix segment and detection rows
# train: /content/EcoVision-2/train/images/frame14_jpg.rf.4ac52eb69d97ce5cc60e7ac8e70ce5cd.jpg: ignoring corrupt image/label: labels mix segment and detection rows
# train: /content/EcoVision-2/train/images/frame14_jpg.rf.72621a3eb2666cf520855ce65763aead.jpg: ignoring corrupt image/label: labels mix segment and detection rows
# train: /content/EcoVision-2/train/images/frame14_jpg.rf.7d2350dac5dcab2bc129bc931e6c243a.jpg: ignoring corrupt image/label: labels mix segment and detection rows
# train: /content/EcoVision-2/train/images/frame14_jpg.rf.f1ac0f47073417a822202a91d40be331.jpg: ignoring corrupt image/label: labels mix segment and detection rows
# train: /content/EcoVision-2/train/images/frame14_jpg.rf.fa0ffec40608b82b1fe6104845c80643.jpg: ignoring corrupt image/label: labels mix segment and detection rows
# train: /content/EcoVision-2/train/images/frame15_jpg.rf.1926d40e3c081ec32c88724f8eb93eb2.jpg: ignoring corrupt image/label: labels mix segment and detection rows
# train: /content/EcoVision-2/train/images/frame15_jpg.rf.275d2d246d357e8eb635c0ba0d88042f.jpg: ignoring corrupt image/label: labels mix segment and detection rows
# train: /content/EcoVision-2/train/images/frame15_jpg.rf.31f6cb38801ceb24540843d86e9f314f.jpg: ignoring corrupt image/label: labels mix segment and detection rows
# train: /content/EcoVision-2/train/images/frame15_jpg.rf.6600190a26432a94d45c2c9fc220404c.jpg: ignoring corrupt image/label: labels mix segment and detection rows
# train: /content/EcoVision-2/train/images/frame15_jpg.rf.729f171368a6503db317460df3445922.jpg: ignoring corrupt image/label: labels mix segment and detection rows
# train: /content/EcoVision-2/train/images/frame15_jpg.rf.7b0262de36539438030760549c8bd85a.jpg: ignoring corrupt image/label: labels mix segment and detection rows
# train: /content/EcoVision-2/train/images/frame15_jpg.rf.8b0493c1f60a784acdb2d384328b6e84.jpg: ignoring corrupt image/label: labels mix segment and detection rows
# train: /content/EcoVision-2/train/images/frame15_jpg.rf.d5c3f2dfe60e0a063caadb0c7fe7a879.jpg: ignoring corrupt image/label: labels mix segment and detection rows
# train: /content/EcoVision-2/train/images/frame15_jpg.rf.dc09475f03fa1a29a5d1e9ec40dcf720.jpg: ignoring corrupt image/label: labels mix segment and detection rows
# train: /content/EcoVision-2/train/images/frame15_jpg.rf.ecf8ca54aea2443f7636290e8f2c4b8d.jpg: ignoring corrupt image/label: labels mix segment and detection rows
# train: /content/EcoVision-2/train/images/frame15_jpg.rf.f45bd134835cec6d0fbc5ef4b6c896b9.jpg: ignoring corrupt image/label: labels mix segment and detection rows
# train: /content/EcoVision-2/train/images/frame16_jpg.rf.162d68bf4dd80b897ba64cf229dc3974.jpg: ignoring corrupt image/label: labels mix segment and detection rows
# train: /content/EcoVision-2/train/images/frame16_jpg.rf.20bd40c75d98b751470a09ad01d9b355.jpg: ignoring corrupt image/label: labels mix segment and detection rows
# train: /content/EcoVision-2/train/images/frame16_jpg.rf.2f898164c57023d0cb44e44e0d9cb69c.jpg: ignoring corrupt image/label: labels mix segment and detection rows
# train: /content/EcoVision-2/train/images/frame16_jpg.rf.6dfd3454ca2ec4bd641056fdc15abedb.jpg: ignoring corrupt image/label: labels mix segment and detection rows
# train: /content/EcoVision-2/train/images/frame16_jpg.rf.897a06bef0d44a7d3cdaa7b4ee74062d.jpg: ignoring corrupt image/label: labels mix segment and detection rows
# train: /content/EcoVision-2/train/images/frame16_jpg.rf.a2699c82e272c8d138f49d6fe71942f1.jpg: ignoring corrupt image/label: labels mix segment and detection rows
# train: /content/EcoVision-2/train/images/frame17_jpg.rf.26d57edf83a60c9ef59d711c0b2d3908.jpg: ignoring corrupt image/label: labels mix segment and detection rows
# train: /content/EcoVision-2/train/images/frame17_jpg.rf.7f1b3c867ca2955315bb5b072bb48817.jpg: ignoring corrupt image/label: labels mix segment and detection rows
# train: /content/EcoVision-2/train/images/frame17_jpg.rf.948b0d0f5f3699d60801994fcfd076a6.jpg: ignoring corrupt image/label: labels mix segment and detection rows
# train: /content/EcoVision-2/train/images/frame19_jpg.rf.18d1266d224691cb911faed1f99e86e8.jpg: ignoring corrupt image/label: labels mix segment and detection rows
# train: /content/EcoVision-2/train/images/frame19_jpg.rf.411cac35cfa181812a64139c666c670b.jpg: ignoring corrupt image/label: labels mix segment and detection rows
# train: /content/EcoVision-2/train/images/frame19_jpg.rf.4195c11ddfde420d502091e7363bcee7.jpg: ignoring corrupt image/label: labels mix segment and detection rows
# train: /content/EcoVision-2/train/images/frame1_jpg.rf.333aa305b348e8e5448f8536904064df.jpg: ignoring corrupt image/label: labels mix segment and detection rows
# train: /content/EcoVision-2/train/images/frame1_jpg.rf.3fb061a391f43b760b9f74ebf8815f68.jpg: ignoring corrupt image/label: labels mix segment and detection rows
# train: /content/EcoVision-2/train/images/frame1_jpg.rf.59980964227844eb1e90193900d8f2b8.jpg: ignoring corrupt image/label: labels mix segment and detection rows
# train: /content/EcoVision-2/train/images/frame1_jpg.rf.8d574ba784b47235ccdeed6ede6d0e1d.jpg: ignoring corrupt image/label: labels mix segment and detection rows
# train: /content/EcoVision-2/train/images/frame1_jpg.rf.b68268fe70c6563c8627a0d807871f39.jpg: ignoring corrupt image/label: labels mix segment and detection rows
# train: /content/EcoVision-2/train/images/frame1_jpg.rf.be570acb1e3b687d68a967565ddbe8ef.jpg: ignoring corrupt image/label: labels mix segment and detection rows
# train: /content/EcoVision-2/train/images/frame21_jpg.rf.14feb49f3b21243b812705da7f3afa4a.jpg: ignoring corrupt image/label: labels mix segment and detection rows
# train: /content/EcoVision-2/train/images/frame21_jpg.rf.241daeea53a777d7bf1a41b1318e1b96.jpg: ignoring corrupt image/label: labels mix segment and detection rows
# train: /content/EcoVision-2/train/images/frame21_jpg.rf.8894fb27cff39baa4270c4bc584875f7.jpg: ignoring corrupt image/label: labels mix segment and detection rows
# train: /content/EcoVision-2/train/images/frame21_jpg.rf.b2f204ea1d199f6a98d8bfbffd78b64d.jpg: ignoring corrupt image/label: labels mix segment and detection rows
# train: /content/EcoVision-2/train/images/frame21_jpg.rf.e03382f6433765f7aa86e65ce75be0a5.jpg: ignoring corrupt image/label: labels mix segment and detection rows
# train: /content/EcoVision-2/train/images/frame21_jpg.rf.e50f91f8d7857c85816ca9a3b07de8e9.jpg: ignoring corrupt image/label: labels mix segment and detection rows
# train: /content/EcoVision-2/train/images/frame25_jpg.rf.b3e19b8ea807b240d7914ff180a13735.jpg: ignoring corrupt image/label: labels mix segment and detection rows
# train: /content/EcoVision-2/train/images/frame25_jpg.rf.c1ea1495b91780be5b1e03cbf965aecc.jpg: ignoring corrupt image/label: labels mix segment and detection rows
# train: /content/EcoVision-2/train/images/frame25_jpg.rf.c6ceb1dd4690ff68d7c856b5debf85fc.jpg: ignoring corrupt image/label: labels mix segment and detection rows
# train: /content/EcoVision-2/train/images/frame27_jpg.rf.004717d6087ceb6f8014ed354ff82143.jpg: ignoring corrupt image/label: labels mix segment and detection rows
# train: /content/EcoVision-2/train/images/frame27_jpg.rf.53b3b6e5133a2f38f68a5b5ed53ff49f.jpg: ignoring corrupt image/label: labels mix segment and detection rows
# train: /content/EcoVision-2/train/images/frame27_jpg.rf.6b1ba8a3b6328e625e976ca6346d0329.jpg: ignoring corrupt image/label: labels mix segment and detection rows
# train: /content/EcoVision-2/train/images/frame27_jpg.rf.b52f023fd8742cc8fae1c04bce08f411.jpg: ignoring corrupt image/label: labels mix segment and detection rows
# train: /content/EcoVision-2/train/images/frame27_jpg.rf.b939277045eff657c4e6aa499297bb3f.jpg: ignoring corrupt image/label: labels mix segment and detection rows
# train: /content/EcoVision-2/train/images/frame27_jpg.rf.dd18d1750a0e73822931f5eed4c58bf5.jpg: ignoring corrupt image/label: labels mix segment and detection rows
# train: /content/EcoVision-2/train/images/frame31_jpg.rf.062accc8405333063012f1e6558193c8.jpg: ignoring corrupt image/label: labels mix segment and detection rows
# train: /content/EcoVision-2/train/images/frame31_jpg.rf.070dd3a89a801c4a145a7df998a50aa4.jpg: ignoring corrupt image/label: labels mix segment and detection rows
# train: /content/EcoVision-2/train/images/frame31_jpg.rf.2b6998fec1f98ffa61190d864b73e88e.jpg: ignoring corrupt image/label: labels mix segment and detection rows
# train: /content/EcoVision-2/train/images/frame31_jpg.rf.3fdf19aa172bf3bcb7233fc93fbbb970.jpg: ignoring corrupt image/label: labels mix segment and detection rows
# ...
#            0.93694,     0.93794,     0.93894,     0.93994,     0.94094,     0.94194,     0.94294,     0.94394,     0.94494,     0.94595,     0.94695,     0.94795,     0.94895,     0.94995,     0.95095,     0.95195,     0.95295,     0.95395,     0.95495,     0.95596,     0.95696,     0.95796,     0.95896,     0.95996,
#            0.96096,     0.96196,     0.96296,     0.96396,     0.96496,     0.96597,     0.96697,     0.96797,     0.96897,     0.96997,     0.97097,     0.97197,     0.97297,     0.97397,     0.97497,     0.97598,     0.97698,     0.97798,     0.97898,     0.97998,     0.98098,     0.98198,     0.98298,     0.98398,
#            0.98498,     0.98599,     0.98699,     0.98799,     0.98899,     0.98999,     0.99099,     0.99199,     0.99299,     0.99399,     0.99499,       0.996,       0.997,       0.998,       0.999,           1]), array([[    0.01797,    0.018039,    0.030001, ...,           1,           1,           1],
#        [   0.098056,    0.098372,     0.15485, ...,           1,           1,           1],
#        [   0.035212,     0.03535,    0.053362, ...,           1,           1,           1],
#        [   0.046434,    0.046571,    0.079547, ...,           1,           1,           1],
#        [   0.028411,    0.028541,    0.052021, ...,           1,           1,           1]]), 'Confidence', 'Precision'], [array([          0,    0.001001,    0.002002,    0.003003,    0.004004,    0.005005,    0.006006,    0.007007,    0.008008,    0.009009,     0.01001,    0.011011,    0.012012,    0.013013,    0.014014,    0.015015,    0.016016,    0.017017,    0.018018,    0.019019,     0.02002,    0.021021,    0.022022,    0.023023,
#           0.024024,    0.025025,    0.026026,    0.027027,    0.028028,    0.029029,     0.03003,    0.031031,    0.032032,    0.033033,    0.034034,    0.035035,    0.036036,    0.037037,    0.038038,    0.039039,     0.04004,    0.041041,    0.042042,    0.043043,    0.044044,    0.045045,    0.046046,    0.047047,
#           0.048048,    0.049049,     0.05005,    0.051051,    0.052052,    0.053053,    0.054054,    0.055055,    0.056056,    0.057057,    0.058058,    0.059059,     0.06006,    0.061061,    0.062062,    0.063063,    0.064064,    0.065065,    0.066066,    0.067067,    0.068068,    0.069069,     0.07007,    0.071071,
#           0.072072,    0.073073,    0.074074,    0.075075,    0.076076,    0.077077,    0.078078,    0.079079,     0.08008,    0.081081,    0.082082,    0.083083,    0.084084,    0.085085,    0.086086,    0.087087,    0.088088,    0.089089,     0.09009,    0.091091,    0.092092,    0.093093,    0.094094,    0.095095,
#           0.096096,    0.097097,    0.098098,    0.099099,      0.1001,      0.1011,      0.1021,      0.1031,      0.1041,     0.10511,     0.10611,     0.10711,     0.10811,     0.10911,     0.11011,     0.11111,     0.11211,     0.11311,     0.11411,     0.11512,     0.11612,     0.11712,     0.11812,     0.11912,
#            0.12012,     0.12112,     0.12212,     0.12312,     0.12412,     0.12513,     0.12613,     0.12713,     0.12813,     0.12913,     0.13013,     0.13113,     0.13213,     0.13313,     0.13413,     0.13514,     0.13614,     0.13714,     0.13814,     0.13914,     0.14014,     0.14114,     0.14214,     0.14314,
#            0.14414,     0.14515,     0.14615,     0.14715,     0.14815,     0.14915,     0.15015,     0.15115,     0.15215,     0.15315,     0.15415,     0.15516,     0.15616,     0.15716,     0.15816,     0.15916,     0.16016,     0.16116,     0.16216,     0.16316,     0.16416,     0.16517,     0.16617,     0.16717,
#            0.16817,     0.16917,     0.17017,     0.17117,     0.17217,     0.17317,     0.17417,     0.17518,     0.17618,     0.17718,     0.17818,     0.17918,     0.18018,     0.18118,     0.18218,     0.18318,     0.18418,     0.18519,     0.18619,     0.18719,     0.18819,     0.18919,     0.19019,     0.19119,
#            0.19219,     0.19319,     0.19419,      0.1952,      0.1962,      0.1972,      0.1982,      0.1992,      0.2002,      0.2012,      0.2022,      0.2032,      0.2042,     0.20521,     0.20621,     0.20721,     0.20821,     0.20921,     0.21021,     0.21121,     0.21221,     0.21321,     0.21421,     0.21522,
#            0.21622,     0.21722,     0.21822,     0.21922,     0.22022,     0.22122,     0.22222,     0.22322,     0.22422,     0.22523,     0.22623,     0.22723,     0.22823,     0.22923,     0.23023,     0.23123,     0.23223,     0.23323,     0.23423,     0.23524,     0.23624,     0.23724,     0.23824,     0.23924,
#            0.24024,     0.24124,     0.24224,     0.24324,     0.24424,     0.24525,     0.24625,     0.24725,     0.24825,     0.24925,     0.25025,     0.25125,     0.25225,     0.25325,     0.25425,     0.25526,     0.25626,     0.25726,     0.25826,     0.25926,     0.26026,     0.26126,     0.26226,     0.26326,
#            0.26426,     0.26527,     0.26627,     0.26727,     0.26827,     0.26927,     0.27027,     0.27127,     0.27227,     0.27327,     0.27427,     0.27528,     0.27628,     0.27728,     0.27828,     0.27928,     0.28028,     0.28128,     0.28228,     0.28328,     0.28428,     0.28529,     0.28629,     0.28729,
#            0.28829,     0.28929,     0.29029,     0.29129,     0.29229,     0.29329,     0.29429,      0.2953,      0.2963,      0.2973,      0.2983,      0.2993,      0.3003,      0.3013,      0.3023,      0.3033,      0.3043,     0.30531,     0.30631,     0.30731,     0.30831,     0.30931,     0.31031,     0.31131,
#            0.31231,     0.31331,     0.31431,     0.31532,     0.31632,     0.31732,     0.31832,     0.31932,     0.32032,     0.32132,     0.32232,     0.32332,     0.32432,     0.32533,     0.32633,     0.32733,     0.32833,     0.32933,     0.33033,     0.33133,     0.33233,     0.33333,     0.33433,     0.33534,
#            0.33634,     0.33734,     0.33834,     0.33934,     0.34034,     0.34134,     0.34234,     0.34334,     0.34434,     0.34535,     0.34635,     0.34735,     0.34835,     0.34935,     0.35035,     0.35135,     0.35235,     0.35335,     0.35435,     0.35536,     0.35636,     0.35736,     0.35836,     0.35936,
#            0.36036,     0.36136,     0.36236,     0.36336,     0.36436,     0.36537,     0.36637,     0.36737,     0.36837,     0.36937,     0.37037,     0.37137,     0.37237,     0.37337,     0.37437,     0.37538,     0.37638,     0.37738,     0.37838,     0.37938,     0.38038,     0.38138,     0.38238,     0.38338,
#            0.38438,     0.38539,     0.38639,     0.38739,     0.38839,     0.38939,     0.39039,     0.39139,     0.39239,     0.39339,     0.39439,      0.3954,      0.3964,      0.3974,      0.3984,      0.3994,      0.4004,      0.4014,      0.4024,      0.4034,      0.4044,     0.40541,     0.40641,     0.40741,
#            0.40841,     0.40941,     0.41041,     0.41141,     0.41241,     0.41341,     0.41441,     0.41542,     0.41642,     0.41742,     0.41842,     0.41942,     0.42042,     0.42142,     0.42242,     0.42342,     0.42442,     0.42543,     0.42643,     0.42743,     0.42843,     0.42943,     0.43043,     0.43143,
#            0.43243,     0.43343,     0.43443,     0.43544,     0.43644,     0.43744,     0.43844,     0.43944,     0.44044,     0.44144,     0.44244,     0.44344,     0.44444,     0.44545,     0.44645,     0.44745,     0.44845,     0.44945,     0.45045,     0.45145,     0.45245,     0.45345,     0.45445,     0.45546,
#            0.45646,     0.45746,     0.45846,     0.45946,     0.46046,     0.46146,     0.46246,     0.46346,     0.46446,     0.46547,     0.46647,     0.46747,     0.46847,     0.46947,     0.47047,     0.47147,     0.47247,     0.47347,     0.47447,     0.47548,     0.47648,     0.47748,     0.47848,     0.47948,
#            0.48048,     0.48148,     0.48248,     0.48348,     0.48448,     0.48549,     0.48649,     0.48749,     0.48849,     0.48949,     0.49049,     0.49149,     0.49249,     0.49349,     0.49449,      0.4955,      0.4965,      0.4975,      0.4985,      0.4995,      0.5005,      0.5015,      0.5025,      0.5035,
#             0.5045,     0.50551,     0.50651,     0.50751,     0.50851,     0.50951,     0.51051,     0.51151,     0.51251,     0.51351,     0.51451,     0.51552,     0.51652,     0.51752,     0.51852,     0.51952,     0.52052,     0.52152,     0.52252,     0.52352,     0.52452,     0.52553,     0.52653,     0.52753,
#            0.52853,     0.52953,     0.53053,     0.53153,     0.53253,     0.53353,     0.53453,     0.53554,     0.53654,     0.53754,     0.53854,     0.53954,     0.54054,     0.54154,     0.54254,     0.54354,     0.54454,     0.54555,     0.54655,     0.54755,     0.54855,     0.54955,     0.55055,     0.55155,
#            0.55255,     0.55355,     0.55455,     0.55556,     0.55656,     0.55756,     0.55856,     0.55956,     0.56056,     0.56156,     0.56256,     0.56356,     0.56456,     0.56557,     0.56657,     0.56757,     0.56857,     0.56957,     0.57057,     0.57157,     0.57257,     0.57357,     0.57457,     0.57558,
#            0.57658,     0.57758,     0.57858,     0.57958,     0.58058,     0.58158,     0.58258,     0.58358,     0.58458,     0.58559,     0.58659,     0.58759,     0.58859,     0.58959,     0.59059,     0.59159,     0.59259,     0.59359,     0.59459,      0.5956,      0.5966,      0.5976,      0.5986,      0.5996,
#             0.6006,      0.6016,      0.6026,      0.6036,      0.6046,     0.60561,     0.60661,     0.60761,     0.60861,     0.60961,     0.61061,     0.61161,     0.61261,     0.61361,     0.61461,     0.61562,     0.61662,     0.61762,     0.61862,     0.61962,     0.62062,     0.62162,     0.62262,     0.62362,
#            0.62462,     0.62563,     0.62663,     0.62763,     0.62863,     0.62963,     0.63063,     0.63163,     0.63263,     0.63363,     0.63463,     0.63564,     0.63664,     0.63764,     0.63864,     0.63964,     0.64064,     0.64164,     0.64264,     0.64364,     0.64464,     0.64565,     0.64665,     0.64765,
#            0.64865,     0.64965,     0.65065,     0.65165,     0.65265,     0.65365,     0.65465,     0.65566,     0.65666,     0.65766,     0.65866,     0.65966,     0.66066,     0.66166,     0.66266,     0.66366,     0.66466,     0.66567,     0.66667,     0.66767,     0.66867,     0.66967,     0.67067,     0.67167,
#            0.67267,     0.67367,     0.67467,     0.67568,     0.67668,     0.67768,     0.67868,     0.67968,     0.68068,     0.68168,     0.68268,     0.68368,     0.68468,     0.68569,     0.68669,     0.68769,     0.68869,     0.68969,     0.69069,     0.69169,     0.69269,     0.69369,     0.69469,      0.6957,
#             0.6967,      0.6977,      0.6987,      0.6997,      0.7007,      0.7017,      0.7027,      0.7037,      0.7047,     0.70571,     0.70671,     0.70771,     0.70871,     0.70971,     0.71071,     0.71171,     0.71271,     0.71371,     0.71471,     0.71572,     0.71672,     0.71772,     0.71872,     0.71972,
#            0.72072,     0.72172,     0.72272,     0.72372,     0.72472,     0.72573,     0.72673,     0.72773,     0.72873,     0.72973,     0.73073,     0.73173,     0.73273,     0.73373,     0.73473,     0.73574,     0.73674,     0.73774,     0.73874,     0.73974,     0.74074,     0.74174,     0.74274,     0.74374,
#            0.74474,     0.74575,     0.74675,     0.74775,     0.74875,     0.74975,     0.75075,     0.75175,     0.75275,     0.75375,     0.75475,     0.75576,     0.75676,     0.75776,     0.75876,     0.75976,     0.76076,     0.76176,     0.76276,     0.76376,     0.76476,     0.76577,     0.76677,     0.76777,
#            0.76877,     0.76977,     0.77077,     0.77177,     0.77277,     0.77377,     0.77477,     0.77578,     0.77678,     0.77778,     0.77878,     0.77978,     0.78078,     0.78178,     0.78278,     0.78378,     0.78478,     0.78579,     0.78679,     0.78779,     0.78879,     0.78979,     0.79079,     0.79179,
#            0.79279,     0.79379,     0.79479,      0.7958,      0.7968,      0.7978,      0.7988,      0.7998,      0.8008,      0.8018,      0.8028,      0.8038,      0.8048,     0.80581,     0.80681,     0.80781,     0.80881,     0.80981,     0.81081,     0.81181,     0.81281,     0.81381,     0.81481,     0.81582,
#            0.81682,     0.81782,     0.81882,     0.81982,     0.82082,     0.82182,     0.82282,     0.82382,     0.82482,     0.82583,     0.82683,     0.82783,     0.82883,     0.82983,     0.83083,     0.83183,     0.83283,     0.83383,     0.83483,     0.83584,     0.83684,     0.83784,     0.83884,     0.83984,
#            0.84084,     0.84184,     0.84284,     0.84384,     0.84484,     0.84585,     0.84685,     0.84785,     0.84885,     0.84985,     0.85085,     0.85185,     0.85285,     0.85385,     0.85485,     0.85586,     0.85686,     0.85786,     0.85886,     0.85986,     0.86086,     0.86186,     0.86286,     0.86386,
#            0.86486,     0.86587,     0.86687,     0.86787,     0.86887,     0.86987,     0.87087,     0.87187,     0.87287,     0.87387,     0.87487,     0.87588,     0.87688,     0.87788,     0.87888,     0.87988,     0.88088,     0.88188,     0.88288,     0.88388,     0.88488,     0.88589,     0.88689,     0.88789,
#            0.88889,     0.88989,     0.89089,     0.89189,     0.89289,     0.89389,     0.89489,      0.8959,      0.8969,      0.8979,      0.8989,      0.8999,      0.9009,      0.9019,      0.9029,      0.9039,      0.9049,     0.90591,     0.90691,     0.90791,     0.90891,     0.90991,     0.91091,     0.91191,
#            0.91291,     0.91391,     0.91491,     0.91592,     0.91692,     0.91792,     0.91892,     0.91992,     0.92092,     0.92192,     0.92292,     0.92392,     0.92492,     0.92593,     0.92693,     0.92793,     0.92893,     0.92993,     0.93093,     0.93193,     0.93293,     0.93393,     0.93493,     0.93594,
#            0.93694,     0.93794,     0.93894,     0.93994,     0.94094,     0.94194,     0.94294,     0.94394,     0.94494,     0.94595,     0.94695,     0.94795,     0.94895,     0.94995,     0.95095,     0.95195,     0.95295,     0.95395,     0.95495,     0.95596,     0.95696,     0.95796,     0.95896,     0.95996,
#            0.96096,     0.96196,     0.96296,     0.96396,     0.96496,     0.96597,     0.96697,     0.96797,     0.96897,     0.96997,     0.97097,     0.97197,     0.97297,     0.97397,     0.97497,     0.97598,     0.97698,     0.97798,     0.97898,     0.97998,     0.98098,     0.98198,     0.98298,     0.98398,
#            0.98498,     0.98599,     0.98699,     0.98799,     0.98899,     0.98999,     0.99099,     0.99199,     0.99299,     0.99399,     0.99499,       0.996,       0.997,       0.998,       0.999,           1]), array([[    0.66063,     0.66063,      0.6145, ...,           0,           0,           0],
#        [    0.85139,     0.85139,     0.83123, ...,           0,           0,           0],
#        [    0.79871,     0.79871,     0.79355, ...,           0,           0,           0],
#        [    0.83377,     0.83247,     0.80519, ...,           0,           0,           0],
#        [    0.69932,     0.69932,      0.6697, ...,           0,           0,           0]]), 'Confidence', 'Recall']]
# fitness: 0.4645785194138538
# keys: ['metrics/precision(B)', 'metrics/recall(B)', 'metrics/mAP50(B)', 'metrics/mAP50-95(B)']
# maps: array([    0.30864,     0.64617,     0.37226,     0.62887,     0.36696])
# names: {0: 'General Waste', 1: 'Glass', 2: 'Metals', 3: 'Paper', 4: 'Plastics'}
# nt_per_class: array([607, 794, 775, 770, 878])
# nt_per_image: array([373, 499, 464, 516, 609])
# results_dict: {'metrics/precision(B)': 0.7101560725549302, 'metrics/recall(B)': 0.516766227880493, 'metrics/mAP50(B)': 0.567761251794305, 'metrics/mAP50-95(B)': 0.4645785194138538, 'fitness': 0.4645785194138538}
# save_dir: PosixPath('/content/runs/garbage_detection/v1')
# speed: {'preprocess': 0.19548227145662056, 'inference': 1.9630035021956627, 'loss': 0.004671718165546353, 'postprocess': 0.30879544431295225}
# stats: {'tp': [], 'conf': [], 'pred_cls': [], 'target_cls': [], 'target_img': []}

# %% [markdown]
# ## 11. Load best model

# %%
best_path = "/content/runs/garbage_detection/v1/weights/best.pt"
v1_model = YOLO(best_path)
print(v1_model.names)
# Out:
# {0: 'General Waste', 1: 'Glass', 2: 'Metals', 3: 'Paper', 4: 'Plastics'}

# %% [markdown]
# ## 12. Evaluate

# %%
metrics = v1_model.val(data=yaml_path, split="test")

print("Precision:", round(metrics.box.mp, 4))
print("Recall:", round(metrics.box.mr, 4))
print("mAP50:", round(metrics.box.map50, 4))
print("mAP50-95:", round(metrics.box.map, 4))
# Out:
# Ultralytics 8.4.135 🚀 Python-3.13.15 torch-2.11.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# YOLO26n summary (fused): 122 layers, 2,375,811 parameters, 0 gradients, 5.3 GFLOPs
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 59.1±69.4 MB/s, size: 281.8 KB)
# val: Scanning /content/EcoVision-2/test/labels... 1087 images, 165 backgrounds, 19 corrupt: 100% ━━━━━━━━━━━━ 1087/1087 582.4it/s 1.9s
# val: /content/EcoVision-2/test/images/20220615_093855_jpg.rf.18b5867c553eb32c6bd8fb4f17f8a132.jpg: ignoring corrupt image/label: labels mix segment and detection rows
# val: /content/EcoVision-2/test/images/20220615_094608_jpg.rf.22287a99e759e7a09475601fa29793e6.jpg: ignoring corrupt image/label: labels mix segment and detection rows
# val: /content/EcoVision-2/test/images/20220615_144804_jpg.rf.ee9710f9c82e40dc96931c355268077d.jpg: ignoring corrupt image/label: labels mix segment and detection rows
# val: /content/EcoVision-2/test/images/20220615_145023_jpg.rf.1ea63ec14f324e5d75805b793c1c16b7.jpg: ignoring corrupt image/label: labels mix segment and detection rows
# val: /content/EcoVision-2/test/images/20220615_145023_jpg.rf.7ee08a66ce20015189b2e241370ba5e8.jpg: ignoring corrupt image/label: labels mix segment and detection rows
# val: /content/EcoVision-2/test/images/20220615_145038_jpg.rf.2b4f4dd835479ba01338c2da7fceb89e.jpg: ignoring corrupt image/label: labels mix segment and detection rows
# val: /content/EcoVision-2/test/images/20220615_150016_jpg.rf.d0d5f7522e0865326b80e60dcb685d43.jpg: ignoring corrupt image/label: labels mix segment and detection rows
# val: /content/EcoVision-2/test/images/20220615_150409_jpg.rf.6c29ff55b9ed37a476d528659692f844.jpg: ignoring corrupt image/label: labels mix segment and detection rows
# val: /content/EcoVision-2/test/images/IMG20220531142222_jpg.rf.056447d17263087f9a0d94a6f273a1fb.jpg: ignoring corrupt image/label: labels mix segment and detection rows
# val: /content/EcoVision-2/test/images/frame12_jpg.rf.df7d7f621365c62d91dcc0524f987019.jpg: ignoring corrupt image/label: labels mix segment and detection rows
# val: /content/EcoVision-2/test/images/frame17_jpg.rf.1760c0e873fa219abf03ce1a4e205ac9.jpg: ignoring corrupt image/label: labels mix segment and detection rows
# val: /content/EcoVision-2/test/images/frame18_jpg.rf.262efe6691998272f7b683b961ff302f.jpg: ignoring corrupt image/label: labels mix segment and detection rows
# val: /content/EcoVision-2/test/images/frame23_jpg.rf.f4b19218a544d03463c16dadccb2c749.jpg: ignoring corrupt image/label: labels mix segment and detection rows
# val: /content/EcoVision-2/test/images/frame8_jpg.rf.ae8dde250e5ef393bdfb08d5a4a300b7.jpg: ignoring corrupt image/label: labels mix segment and detection rows
# val: /content/EcoVision-2/test/images/glass_image-215-_jpg.rf.c9ba435365a803cd4cc1c9b284ca4ea3.jpg: ignoring corrupt image/label: labels mix segment and detection rows
# val: /content/EcoVision-2/test/images/metal_image-52-_jpg.rf.fdc14cab3633ae571394bd6c629fcb19.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [1.0287731 1.3887079]
# val: /content/EcoVision-2/test/images/paper_image-44-_jpg.rf.48c51d6c2741f00e60fa04cabb23d10a.jpg: ignoring corrupt image/label: labels mix segment and detection rows
# val: /content/EcoVision-2/test/images/paper_image-52-_jpg.rf.5a6695928e942aa28816bcbb53c7d6ee.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [1.0188802]
# val: /content/EcoVision-2/test/images/paper_image-90-_jpg.rf.dca8a8cd4cb4bc1eadb312898c4d5719.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [1.0546875]
# val: New cache created: /content/EcoVision-2/test/labels.cache
# WARNING ⚠️ Box and segment counts should be equal, but got len(segments) = 661, len(boxes) = 1470. To resolve this only boxes will be used and all segments will be removed. To avoid this please supply either a detect or segment dataset, not a detect-segment mixed dataset.
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 67/67 4.8it/s 13.9s
#                    all       1068       1470      0.787      0.573      0.656      0.533
#          General Waste        163        247      0.822      0.482      0.613      0.458
#                  Glass        237        353      0.886      0.776      0.835       0.72
#                 Metals        171        335      0.645      0.471      0.529      0.378
#                  Paper        247        352      0.902      0.693      0.803      0.714
#               Plastics        135        183      0.678      0.443      0.502      0.397
# Speed: 1.5ms preprocess, 5.5ms inference, 0.0ms loss, 0.3ms postprocess per image
# Results saved to /content/runs/detect/val
# Precision: 0.7866
# Recall: 0.5729
# mAP50: 0.6564
# mAP50-95: 0.5332

# %% [markdown]
# ## 13. Per-class mAP50-95

# %%
for name, score in zip(v1_model.names.values(), metrics.box.maps):
    print(name, ":", round(float(score), 4))
# Out:
# General Waste : 0.4575
# Glass : 0.7196
# Metals : 0.3777
# Paper : 0.7141
# Plastics : 0.3969

# %% [markdown]
# ## 14. Test images

# %%
results = v1_model(test_images[:10], conf=0.25)

for result in results:
    result.show()
# Out:
# 0: 640x640 1 Glass, 4.7ms
# 1: 640x640 1 General Waste, 4.7ms
# 2: 640x640 1 Metals, 1 Paper, 4.7ms
# 3: 640x640 1 Glass, 4.7ms
# 4: 640x640 (no detections), 4.7ms
# 5: 640x640 2 Papers, 4.7ms
# 6: 640x640 1 Paper, 4.7ms
# 7: 640x640 (no detections), 4.7ms
# 8: 640x640 1 Paper, 4.7ms
# 9: 640x640 4 Glasss, 4.7ms
# Speed: 3.1ms preprocess, 4.7ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
# <PIL.Image.Image image mode=RGB size=408x612>
# <PIL.Image.Image image mode=RGB size=600x400>
# <PIL.Image.Image image mode=RGB size=1536x2048>
# <PIL.Image.Image image mode=RGB size=415x612>
# <PIL.Image.Image image mode=RGB size=1808x2048>
# <PIL.Image.Image image mode=RGB size=959x1471>
# <PIL.Image.Image image mode=RGB size=300x300>
# <PIL.Image.Image image mode=RGB size=2000x1619>
# <PIL.Image.Image image mode=RGB size=300x300>
# <PIL.Image.Image image mode=RGB size=1536x2048>

# %%
from IPython.display import Image, display

display(Image(
    filename="/content/runs/detect/val/confusion_matrix.png",
    width=800
))
